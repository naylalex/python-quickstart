# %% [markdown]
# # Introduction to Python

# %%
import numpy as np
np.__version__
# Out:
# '1.21.2'
# Bad pipe message: %s [b'\x05I\xd8F^\xed\x9f\xeb%@2v\xe5x\x8c\xe3\xa3\x8e ']
# Bad pipe message: %s [b"\xa5q\x9d\x95\x7fpw\xb3\x8d\xbd\xe5\xc7\xbf\tga\xa3\xca u\xd0\xd4A\xd6\x1b~\x1c\xb2-\x84I\x86R\x93\x1f[\xf0\xdd\x86\xf6\xfa\x94'\x11\xa8L\xf4|\xbb\x14q\x00\x08\x13\x02\x13\x03\x13\x01\x00\xff\x01\x00\x00\x8f\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x0c\x00\n\x00\x1d\x00\x17\x00\x1e\x00\x19\x00\x18\x00#\x00\x00\x00\x16\x00\x00\x00\x17\x00\x00\x00\r\x00\x1e\x00\x1c\x04\x03\x05\x03\x06\x03\x08\x07\x08\x08\x08\t\x08\n\x08\x0b\x08\x04\x08\x05\x08\x06\x04\x01\x05\x01\x06\x01\x00+\x00\x03\x02\x03\x04\x00-\x00\x02\x01\x01\x003\x00&\x00$\x00\x1d\x00"]
# ...

# %%
a = np.array([1, 2, 3])
b = np.random.randn(3,3)
a.dot(b)
# Out:
# array([-4.23747881, -2.20673546, -1.79822905])

# %%
import pandas as pd
pd.__version__
# Out:
# '1.3.4'
